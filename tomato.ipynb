# %% [markdown]
# ## Clonando o DataSet

# %%
# !git clone https://github.com/sarviovalente/dataset_tomate
# Out:
# Cloning into 'dataset_tomate'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %% [markdown]
# ## Importação de blibiotecas

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %% [markdown]
# ## Definindo Classe e Previsores

# %%
csv = pd.read_csv("dataset_tomate/dataset_tomate.csv")

# %% [markdown]
# Foi verificado em todas as colunas e não teve nenhum dado faltante

# %%
csv.isnull().sum().sort_values(ascending = False)

# %% [markdown]
# No pré-processamento de dados foi retirado a coluna Id (Dado categórico)

# %%
csv.drop(axis=1, columns="id", inplace=True)

# %%
x = csv.iloc[:,list(range(0,21))]
y = csv.iloc[:,[-1]]

# %% [markdown]
# ## Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
x_train
# Out:
#      trat  NDVI_d28  SAVI_d28  ...  GNDVI_d08   MCARI1_d08    SR_d08
# 91    304  0.768295  1.152399  ...   0.689930  17249.33047  7.608741
# 95    311  0.787429  1.181106  ...   0.719745  20623.24509  9.174991
# 129    84  0.781299  1.171903  ...   0.626687  13901.73759  5.240016
# 28    154  0.769338  1.153958  ...   0.651448  12513.64135  5.973544
# 60    234  0.777222  1.165787  ...   0.639732  12324.76210  5.473101
# ..    ...       ...       ...  ...        ...          ...       ...
# 100   332  0.702853  1.054238  ...   0.632440  16155.19752  6.366358
# 8     111  0.790080  1.185074  ...   0.649362  14597.79894  6.153231
# 73    261  0.765601  1.148357  ...   0.657103  14044.98470  6.466628
# 118    71  0.782725  1.174042  ...   0.645868  14201.17261  5.973568
# 99    334  0.666665  0.999954  ...   0.626415  14428.77128  5.717155
#
# [105 rows x 21 columns]

# %%
x_test
# Out:
#      trat  NDVI_d28  SAVI_d28  ...  GNDVI_d08   MCARI1_d08    SR_d08
# 52    214  0.780903  1.171305  ...   0.654742  11536.11861  5.528516
# 90    302  0.766088  1.149089  ...   0.694733  17933.29543  8.179210
# 42    203  0.825696  1.238498  ...   0.650380  12635.83173  5.762495
# 116    53  0.701226  1.051788  ...   0.593515  14350.54472  5.414653
# 106   321  0.777472  1.166167  ...   0.690388  15247.61085  7.111258
# 56     23  0.793706  1.190514  ...   0.700441  22391.41245  8.757980
# 66    251  0.755185  1.132733  ...   0.644887  13417.07846  5.800065
# 21    161  0.772799  1.159151  ...   0.702535  16837.38576  8.234412
# 35    182  0.804871  1.207260  ...   0.664264  14561.50962  6.455969
# 48    202  0.799377  1.199020  ...   0.651379  13678.63166  6.070063
# 23    151  0.780630  1.170899  ...   0.658407  15198.20938  6.479915
# 10    122  0.787846  1.181722  ...   0.641294  14630.45708  6.313308
# 72    242  0.804183  1.206230  ...   0.661932  13817.81919  6.332899
# ...

# %%
y_train
# Out:
#      Classe
# 91        0
# 95        0
# 129       1
# 28        1
# 60        1
# ..      ...
# 100       0
# 8         1
# 73        1
# 118       1
# 99        0
#
# [105 rows x 1 columns]

# %%
y_test
# Out:
#      Classe
# 52        1
# 90        0
# 42        1
# 116       1
# 106       1
# 56        0
# 66        1
# 21        0
# 35        1
# 48        1
# 23        1
# 10        1
# 72        1
# 37        0
# 92        0
# 87        0
# 71        1
# 57        0
# 110       0
# 119       0
# 17        1
# 20        1
# 25        1
# 74        1
# 6         1
# 130       1
# 127       1

# %% [markdown]
# ## Teste de modelos

# %% [markdown]
# Foram utilizados os seguintes algoritmos: Support Vector Machine e
# Stochastic gradient descent para a confecção de testes, cujo o SGD obteve a melhor performance. Utilizamos o método *classification_report()* pois o mesmo nos retorna a precisão, recall, f1-sore, support, acurácia, macro avg, weighted avg.

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
svc_model= SVC()
svc_model.fit(x_train,y_train)
y_predict_svc= svc_model.predict(x_test)
print(classification_report(y_test,y_predict_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.44      0.62         9
#            1       0.78      1.00      0.88        18
#
#     accuracy                           0.81        27
#    macro avg       0.89      0.72      0.75        27
# weighted avg       0.86      0.81      0.79        27
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### SGD

# %%
from sklearn.linear_model import SGDClassifier
sgd_model = SGDClassifier(random_state=42)
sgd_model.fit(x_train, y_train)
y_predict_sgd= s.predict(x_test)
print(classification_report(y_test,y_predict_sgd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90         9
#            1       1.00      0.89      0.94        18
#
#     accuracy                           0.93        27
#    macro avg       0.91      0.94      0.92        27
# weighted avg       0.94      0.93      0.93        27
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
